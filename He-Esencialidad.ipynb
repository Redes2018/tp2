# %%
import sys
sys.path.append('/usr/local/lib/python3.5/site-packages')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import os

# %%
carpeta = (os.getcwd()+'/tc02Data/')

# Creo un dataframe con las proteinas esenciales, pero el primer elemento es parte del encabezado
# podria eliminarlo con header pero si agrego lineas a header no puedo seleccionar columnas con usecols
data = pd.read_csv(carpeta+'Essential_ORFs_paperHe.txt', sep='\t', header=0,skipfooter=4,usecols=[1])

# Como algunos nombres de proteinas terminan con "  " hay que borrar los espacios vacios
data['ORF_name'] = data['ORF_name'].map(lambda x: x.strip()) 

# Me puedo quedar con la serie de pandas o puedo hacer una lista, eliminando el primer elemento que sobraba
ess = data["ORF_name"].tolist()
del ess[0]
# ess es una lista con los nombres de las proteinas esenciales

G = []
G.append(set(ess))

#Acá le agrego los demás archivos y los transformo en sets para trabajar más facil
archivos = ['Y2H','AP-MS','LIT','LIT_Reguly']
for j,arc in enumerate(archivos):
    data = pd.read_csv(carpeta+'yeast_'+arc+'.txt', sep='\t', header=None)
    G0 = nx.Graph()
    for i in range(len(data)):
        G0.add_edges_from([(data[0][i],data[1][i])])
    G.append(set(G0))
# Out:
# C:\Users\lucio\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """

# %%
#Busco las intersecciones y despues las localizo en los grafos y calculo su grado
intersecciones =[]

for i in range(1,len(G)):
    intersecciones.append(G[0].intersection(G[i]))

# %%
grados = []
lugares=[]

for j in range(len(intersecciones)):
    ls=list(intersecciones[j]) #las interacciones en lugar de ser sets ahora son listas
    g=list(G[j+1]) #y los grafos tambien
    for i in range(len(ls)):
        np.where(ls==g)
            G.degree
# Out:
#   File "<ipython-input-27-6b3bd44525d8>", line 1
#     intersecciones[0]{0}
#                      ^
# SyntaxError: invalid syntax

# %%
ls=list(intersecciones[0]) #las interacciones en lugar de ser sets ahora son listas
g=list(G[1]) 
np.where([g==ls])
# Out:
# (array([], dtype=int64),)

# %%
g
# Out:
# ['YEL060C',
#  'YEL034W',
#  'YFL060C',
#  'YEL032W',
#  'YHR066W',
#  'YDL005C',
#  'YOR124C',
#  'YNL042W',
#  'YNR025C',
#  'YLR031W',
#  'YDR190C',
#  'YGL024W',
#  'YBR102C',
#  'YNL225C',
#  'YPL131W',
#  'YER052C',
#  'YDR364C',
#  'YBL056W',
#  'YNL020C',
#  'YOR247W',
#  'YGR268C',
#  'YDR082W',
#  'YLR433C',
#  'YBL045C',
#  'YJR133W',
#  'YCR057C',
#  'YGR154C',
#  'YOR054C',
#  'YER087CA',
#  'YML041C',
#  'YPR160W',
#  'YDR086C',
#  'YML088W',
#  'YDR504C',
#  'YNL147W',
#  'YGR066C',
#  'YKR094C',
#  'YDR399W',
#  'YPL233W',
#  'YJR073C',
#  'YLR025W',
#  'YGR203W',
#  'YKL008C',
#  'YKL197C',
#  'YGR120C',
#  'YLR070C',
#  'YHR158C',
#  'YHR106W',
#  'YGL026C',
#  'YOR042W',
#  'YKR022C',
#  'YGL158W',
#  'YOR276W',
#  'YEL018W',
#  'YPR115W',
#  'YPL157W',
#  'YDR382W',
#  'YOR223W',
#  'YFR007W',
#  'YHL009C',
#  'YKL061W',
#  'YCR066W',
#  'YBR205W',
#  'YBR222C',
#  'YIL033C',
#  'YPR171W',
#  'YCR045C',
#  'YMR261C',
#  'YOR301W',
#  'YHR193C',
#  'YDL002C',
#  'YLR208W',
#  'YJL097W',
#  'YJL134W',
#  'YCR060W',
#  'YER063W',
#  'YNR030W',
#  'YPR126C',
#  'YDR312W',
#  'YPL053C',
#  'YJL031C',
#  'YLR323C',
#  'YDL190C',
#  'YDR229W',
#  'YER043C',
#  'YJR050W',
#  'YER065C',
#  'YBR034C',
#  'YBR101C',
#  'YJL068C',
#  'YPL038W',
#  'YFL039C',
#  'YCL029C',
#  'YGL233W',
#  'YJL218W',
#  'YDL209C',
#  'YOR101W',
#  'YDR051C',
#  'YGL221C',
#  'YDR140W',
#  'YER071C',
#  'YGR010W',
#  'YGR047C',
#  'YAR018C',
#  'YHR026W',
#  'YGR068C',
#  'YNR034W',
#  'YKR062W',
#  'YMR228W',
#  'YOL065C',
#  'YDL132W',
#  'YJL057C',
#  'YLR447C',
#  'YAL041W',
#  'YML011C',
#  'YGL237C',
#  'YHR098C',
#  'YCL040W',
#  'YDL224C',
#  'YJR068W',
#  'YLR186W',
#  'YBR006W',
#  'YMR165C',
#  'YPR088C',
#  'YHR090C',
#  'YHR025W',
#  'YGR134W',
#  'YBR072W',
#  'YBR289W',
#  'YDR421W',
#  'YIL018W',
#  'YIR005W',
#  'YBR194W',
#  'YDR245W',
#  'YJR022W',
#  'YGL223C',
#  'YOR368W',
#  'YOR102W',
#  'YGL252C',
#  'YDR416W',
#  'YDR411C',
#  'YDR441C',
#  'YGL214W',
#  'YNL102W',
#  'YIL119C',
#  'YIR044C',
#  'YGL044C',
#  'YOL133W',
#  'YOL123W',
#  'YJL189W',
#  'YJL183W',
#  'YNL007C',
#  'YLL060C',
#  'YDR142C',
#  'YGL144C',
#  'YDR381W',
#  'YDR203W',
#  'YKR059W',
#  'YKL204W',
#  'YGR209C',
#  'Q0085',
#  'YDL126C',
#  'YDR225W',
#  'YML055W',
#  'YGL053W',
#  'YLR052W',
#  'YLR166C',
#  'YDR299W',
#  'YER146W',
#  'YLR096W',
#  'YPR028W',
#  'YER101C',
#  'YGL250W',
#  'MEL1',
#  'YLR273C',
#  'YHL027W',
#  'YGL094C',
#  'YOR155C',
#  'YBR188C',
#  'YBL042C',
#  'YLR026C',
#  'YKL012W',
#  'YGR136W',
#  'YBR052C',
#  'YDL070W',
#  'YDL157C',
#  'YLR453C',
#  'YLR011W',
#  'YGR004W',
#  'YGR155W',
#  'YHR207C',
#  'YPL110C',
#  'YDL189W',
#  'YHR074W',
#  'YPR158W',
#  'YCR023C',
#  'YNL236W',
#  'YDL089W',
#  'YJR072C',
#  'YBR217W',
#  'YDL118W',
#  'YML110C',
#  'YFL003C',
#  'YLR182W',
#  'YJL030W',
#  'YDR527W',
#  'YOR258W',
#  'YNL032W',
#  'YBR198C',
#  'YOL067C',
#  'YOL148C',
#  'YDR177W',
#  'YJR102C',
#  'YNL258C',
#  'YKR064W',
#  'YDR162C',
#  'YDR059C',
#  'YLR393W',
#  'YBR176W',
#  'YDR016C',
#  'YNL023C',
#  'YMR270C',
#  'YPL173W',
#  'YDR431W',
#  'YJL124C',
#  'YJL180C',
#  'YER105C',
#  'YGL004C',
#  'YLR345W',
#  'YIL104C',
#  'YNL181W',
#  'YGR179C',
#  'YPL019C',
#  'YDR465C',
#  'YCR063W',
#  'YKL033W',
#  'YMR030W',
#  'YIL008W',
#  'YDR503C',
#  'YCR050C',
#  'YCR093W',
#  'YML114C',
#  'YNL178W',
#  'YIL084C',
#  'YDL237W',
#  'YAL021C',
#  'YOL012C',
#  'YEL072W',
#  'YPR159CA',
#  'YLR206W',
#  'YGL189C',
#  'YLR021W',
#  'YKL068W',
#  'YAR033W',
#  'YHL006C',
#  'YMR294W',
#  'YHR129C',
#  'YJL104W',
#  'YDR388W',
#  'YLR268W',
#  'YML079W',
#  'YER024W',
#  'YOL089C',
#  'YMR047C',
#  'YBR130C',
#  'YJR122W',
#  'YGR129W',
#  'YHL003C',
#  'YHR022C',
#  'YIR015W',
#  'YOR269W',
#  'YHL004W',
#  'YPL094C',
#  'YDL084W',
#  'YPL259C',
#  'YLL019C',
#  'YMR309C',
#  'YDL239C',
#  'YJL083W',
#  'YGR046W',
#  'YPR071W',
#  'YGL134W',
#  'YOL107W',
#  'YOR127W',
#  'YDL139C',
#  'YER157W',
#  'YBR254C',
#  'YGL051W',
#  'YML014W',
#  'YGR133W',
#  'YLR466W',
#  'YER180C',
#  'YLR319C',
#  'YIL050W',
#  'YIL092W',
#  'YDR240C',
#  'YDR513W',
#  'YPR159W',
#  'YJR011C',
#  'YGR188C',
#  'YIL144W',
#  'YLR030W',
#  'YBR270C',
#  'YFL029C',
#  'YJR141W',
#  'YMR028W',
#  'YLR223C',
#  'YML023C',
#  'YGR233C',
#  'YAL032C',
#  'YPR049C',
#  'YHR107C',
#  'YKL002W',
#  'YFR008W',
#  'YKR096W',
#  'YIL065C',
#  'YBR055C',
#  'YNL001W',
#  'YPR153W',
#  'YDR308C',
#  'YJR086W',
#  'YLR362W',
#  'YPL108W',
#  'YLR049C',
#  'YHR033W',
#  'YOR380W',
#  'YDR034C',
#  'YDL235C',
#  'YPL175W',
#  'YLR006C',
#  'YPR185W',
#  'YOR220W',
#  'YPR152C',
#  'YGL229C',
#  'YIR034C',
#  'YHR197W',
#  'YBR030W',
#  'YDL166C',
#  'YDR027C',
#  'YGR232W',
#  'YGL124C',
#  'YLR373C',
#  'YHR185C',
#  'YMR153W',
#  'YPL267W',
#  'YDR323C',
#  'YBR141C',
#  'YML121W',
#  'YOR162C',
#  'YOL131W',
#  'YOR185C',
#  'YMR226C',
#  'YDR128W',
#  'YER009W',
#  'YPL002C',
#  'YML031W',
#  'YEL043W',
#  'YHR137W',
#  'YJL173C',
#  'YNR007C',
#  'YLL028W',
#  'YDR138W',
#  'YDR373W',
#  'YPL255W',
#  'YMR067C',
#  'YOL018C',
#  'YOR355W',
#  'YBL071WA',
#  'YNL041C',
#  'YDL121C',
#  'YEL056W',
#  'YDR477W',
#  'YER070W',
#  'YKL040C',
#  'YOR284W',
#  'YBL033C',
#  'YER143W',
#  'YLR014C',
#  'YOR285W',
#  'YDR194C',
#  'YBR170C',
#  'YGR048W',
#  'YDR073W',
#  'YHR035W',
#  'YLR065C',
#  'YLR405W',
#  'YLR102C',
#  'YML101C',
#  'YBR153W',
#  'YDR311W',
#  'YDR453C',
#  'YHR113W',
#  'YDR098C',
#  'YPL211W',
#  'YMR163C',
#  'YLR258W',
#  'YKR043C',
#  'YMR193W',
#  'YJL151C',
#  'YER099C',
#  'YMR141C',
#  'YML056C',
#  'YJR094C',
#  'YPL111W',
#  'YEL029C',
#  'YDR099W',
#  'YGR081C',
#  'YDR123C',
#  'YNL333W',
#  'YLL017W',
#  'YBR087W',
#  'YPR020W',
#  'YDL071C',
#  'YOL109W',
#  'YKL211C',
#  'YLR287C',
#  'YPR105C',
#  'YGR075C',
#  'YLR303W',
#  'YOR138C',
#  'YLL010C',
#  'YKL130C',
#  'YOR181W',
#  'YJL058C',
#  'YGR205W',
#  'YBR154C',
#  'YEL062W',
#  'YMR125W',
#  'YHR016C',
#  'YMR180C',
#  'YML092C',
#  'YGL180W',
#  'YGL015C',
#  'YBR126C',
#  'YFR047C',
#  'YNL056W',
#  'YPL125W',
#  'YER027C',
#  'YOR115C',
#  'YDR146C',
#  'YDR479C',
#  'YGR294W',
#  'YNL124W',
#  'YER177W',
#  'YER133W',
#  'YDL073W',
#  'YDR469W',
#  'YGL115W',
#  'YOR128C',
#  'YDR092W',
#  'YFL024C',
#  'YJR083C',
#  'YDR192C',
#  'YGL192W',
#  'YJL157C',
#  'YDR171W',
#  'YMR043W',
#  'YLR243W',
#  'YHL025W',
#  'YIL026C',
#  'YOR020C',
#  'YNL094W',
#  'YER112W',
#  'YIL053W',
#  'YMR102C',
#  'YPL037C',
#  'YIL163C',
#  'YGL213C',
#  'YLR322W',
#  'YJL088W',
#  'YNL086W',
#  'YNR011C',
#  'YBR196C',
#  'YOR303W',
#  'YJL001W',
#  'YGR250C',
#  'YBR278W',
#  'YMR033W',
#  'YKL039W',
#  'YOL059W',
#  'YMR052W',
#  'YOL111C',
#  'YOR005C',
#  'YER026C',
#  'YDL130W',
#  'YJR010W',
#  'YDR313C',
#  'YGR144W',
#  'YER090W',
#  'YOL149W',
#  'YNR051C',
#  'YPL091W',
#  'YNL218W',
#  'YML007W',
#  'YPR066W',
#  'YNL239W',
#  'YLR295C',
#  'YPR143W',
#  'YDR159W',
#  'YCR077C',
#  'YPR135W',
#  'YDR518W',
#  'YOR321W',
#  'YLR266C',
#  'YNL244C',
#  'YPL260W',
#  'YKL038W',
#  'YGR161CC',
#  'YOR178C',
#  'YAR031W',
#  'YER095W',
#  'YLR390W',
#  'YLR200W',
#  'YFL018C',
#  'YGR173W',
#  'YLR058C',
#  'YML094W',
#  'YDL045C',
#  'YCL032W',
#  'YMR232W',
#  'YDL017W',
#  'YCR030C',
#  'YKL090W',
#  'YIL150C',
#  'YPR183W',
#  'YDL053C',
#  'YHR123W',
#  'YPR104C',
#  'YDL164C',
#  'YIL124W',
#  'YMR276W',
#  'YDR394W',
#  'YIR003W',
#  'YMR129W',
#  'YOL094C',
#  'YGL170C',
#  'YPR054W',
#  'YMR243C',
#  'YPR083W',
#  'YGR213C',
#  'YNL113W',
#  'YDR179C',
#  'YDR398W',
#  'YMR201C',
#  'YMR087W',
#  'YHR145C',
#  'YLR215C',
#  'YPL190C',
#  'YLR245C',
#  'YEL051W',
#  'YGL013C',
#  'YDL111C',
#  'YPR182W',
#  'YJL153C',
#  'YBR276C',
#  'YHR215W',
#  'YEL020C',
#  'YMR317W',
#  'YJL135W',
#  'YDR261WA',
#  'YKL157W',
#  'YNR005C',
#  'YDR174W',
#  'YPL209C',
#  'YDR472W',
#  'YGL112C',
#  'YDL238C',
#  'YDR476C',
#  'YLL046C',
#  'YMR059W',
#  'YDR052C',
#  'YGR229C',
#  'YOR117W',
#  'YLR082C',
#  'YGR113W',
#  'YIL085C',
#  'YOL106W',
#  'YLR209C',
#  'YKL070W',
#  'YER134C',
#  'YGL156W',
#  'YML043C',
#  'YLR227C',
#  'TORF19',
#  'YAR066W',
#  'YDL098C',
#  'YDR071C',
#  'YNL024C',
#  'YCR068W',
#  'YNL063W',
#  'YKL191W',
#  'YOL050C',
#  'YDL165W',
#  'YJR047C',
#  'YGL238W',
#  'YMR077C',
#  'YOR171C',
#  'YNL279W',
#  'YOR377W',
#  'YDL066W',
#  'YNL153C',
#  'YPL003W',
#  'YDL133CA',
#  'YJR044C',
#  'YGL116W',
#  'YGR014W',
#  'YDR489W',
#  'YER086W',
#  'YHR131C',
#  'YLR180W',
#  'YBL101C',
#  'YER047C',
#  'YFR027W',
#  'YML075C',
#  'YDR400W',
#  'YGR122W',
#  'YIL105WA',
#  'YAL055W',
#  'YDR233C',
#  'YDR088C',
#  'YDR207C',
#  'YGR017W',
#  'YBR150C',
#  'YIL152W',
#  'YCL063W',
#  'YMR039C',
#  'YFL028C',
#  'YJL092W',
#  'YDR386W',
#  'YDL015C',
#  'YLR150W',
#  'YIL045W',
#  'YCL010C',
#  'YGR261C',
#  'YBL007C',
#  'YDL134C',
#  'YDR264C',
#  'YLR389C',
#  'YBR237W',
#  'YGL091C',
#  'YBR253W',
#  'YHR160C',
#  'YLR263W',
#  'YBR040W',
#  'YLR421C',
#  'YDL133W',
#  'YKL001C',
#  'YPR022C',
#  'YML034W',
#  'YAL016W',
#  'YDR017C',
#  'YDR412W',
#  'YMR223W',
#  'YDR418W',
#  'YNL161W',
#  'YLL014W',
#  'YPL161C',
#  'YBL035C',
#  'YLR442C',
#  'YNL091W',
#  'YJL056C',
#  'YDL056W',
#  'YOR304CA',
#  'YOR037W',
#  'YLL057C',
#  'YNR039C',
#  'YGR218W',
#  'YAL034WA',
#  'YGR040W',
#  'YCR035C',
#  'YBR137W',
#  'YDL113C',
#  'YNL171C',
#  'YOR089C',
#  'YOL021C',
#  'YLR275W',
#  'YKL103C',
#  'YJL075C',
#  'YGR239C',
#  'YDL101C',
#  'YLR270W',
#  'YNL025C',
#  'YML025C',
#  'YBR125C',
#  'YJL019W',
#  'YJR010CA',
#  'YLR222C',
#  'YCR027C',
#  'YLR229C',
#  'YGL153W',
#  'YBL101WA',
#  'YOR192CA',
#  'YKR048C',
#  'YOR097C',
#  'YOL036W',
#  'YGR104C',
#  'YIL051C',
#  'YKL192C',
#  'YDR121W',
#  'YLR284C',
#  'YKL019W',
#  'YLR440C',
#  'YIR017C',
#  'YGR110W',
#  'YML053C',
#  'YMR316W',
#  'YKR084C',
#  'YGL166W',
#  'YPL159C',
#  'YHL039W',
#  'YHR036W',
#  'YBR212W',
#  'YGR077C',
#  'YNL229C',
#  'YOL069W',
#  'YFR042W',
#  'YBR201W',
#  'YDR261WB',
#  'YER149C',
#  'YDL215C',
#  'YKL132C',
#  'YDR206W',
#  'YPL004C',
#  'YOR318C',
#  'YPL235W',
#  'YHR076W',
#  'YOR361C',
#  'YLR291C',
#  'YBR242W',
#  'YGL145W',
#  'YML029W',
#  'YNL228W',
#  'YNR032CA',
#  'YDR372C',
#  'YBR057C',
#  'YJR084W',
#  'YLR465C',
#  'YPL228W',
#  'YMR300C',
#  'YPL020C',
#  'YDR110W',
#  'YOL129W',
#  'YER182W',
#  'YKL151C',
#  'YDR236C',
#  'YDR482C',
#  'YOL088C',
#  'YGR097W',
#  'YBR126WA',
#  'YDL031W',
#  'YDR214W',
#  'YLR238W',
#  'YJR103W',
#  'YPL114W',
#  'YDR259C',
#  'YDL006W',
#  'YGL198W',
#  'YJL072C',
#  'YER025W',
#  'YOR159C',
#  'YPR149W',
#  'YPL208W',
#  'YDL065C',
#  'YLR293C',
#  'YDL161W',
#  'YGL126W',
#  'YMR079W',
#  'YDL097C',
#  'YPL204W',
#  'YHR156C',
#  'YDL106C',
#  'YLR420W',
#  'YHR204W',
#  'YMR227C',
#  'YJL064W',
#  'YGL028C',
#  'YPL266W',
#  'YGL096W',
#  'YEL015W',
#  'YEL005C',
#  'YPR148C',
#  'YMR154C',
#  'YMR236W',
#  'YLR244C',
#  'YOL108C',
#  'YPL105C',
#  'YOL139C',
#  'YLR112W',
#  'YBR252W',
#  'YBR152W',
#  'YMR255W',
#  'YNL217W',
#  'YBR264C',
#  'YML125C',
#  'YDR173C',
#  'YOR362C',
#  'YDL030W',
#  'YLR059C',
#  'YMR224C',
#  'YNL044W',
#  'YOR229W',
#  'YKL214C',
#  'YKL010C',
#  'YOR332W',
#  'YER131W',
#  'YOR161C',
#  'YCR004C',
#  'YGR125W',
#  'YOL006C',
#  'YNR012W',
#  'YAR007C',
#  'YDR084C',
#  'YPL088W',
#  'YEL023C',
#  'YCL066W',
#  'YHR058C',
#  'YMR288W',
#  'YIR018W',
#  'YGL087C',
#  'YDR252W',
#  'YLR392C',
#  'YGR049W',
#  'YJR130C',
#  'YDR488C',
#  'YHR170W',
#  'YLR403W',
#  'YAL054C',
#  'YBL077W',
#  'YDL147W',
#  'YDR020C',
#  'YBR133C',
#  'YML108W',
#  'YPR158WA',
#  'YJL127WA',
#  'YCR036W',
#  'YJL199C',
#  'YHR166C',
#  'YLR368W',
#  'YBR111C',
#  'YPR037C',
#  'YBL102W',
#  'YPR173C',
#  'YOR123C',
#  'YPL151C',
#  'YDL125C',
#  'YIL160C',
#  'YGR092W',
#  'YPL268W',
#  'YNR052C',
#  'YHR112C',
#  'YER107C',
#  'YCL039W',
#  'YDL110C',
#  'YLR125W',
#  'YML109W',
#  'YJR049C',
#  'YLR312C',
#  'YCL019W',
#  'YGR130C',
#  'YNR046W',
#  'YBL046W',
#  'YDR473C',
#  'YER059W',
#  'YCR021C',
#  'YFL038C',
#  'YJL121C',
#  'YBL020W',
#  'YGR223C',
#  'YDR189W',
#  'YDR070C',
#  'YPR172W',
#  'YJL141C',
#  'YJL117W',
#  'YNL054WB',
#  'YGL092W',
#  'YMR210W',
#  'YMR316CB',
#  'YKL135C',
#  'YDR520C',
#  'YBR080C',
#  'YML071C',
#  'YDR212W',
#  'YGR027C',
#  'YGR041W',
#  'YMR104C',
#  'YNL021W',
#  'YDL149W',
#  'YPL140C',
#  'YPL059W',
#  'YOL054W',
#  'YJR112W',
#  'YKL212W',
#  'YPL070W',
#  'YDL226C',
#  'YOR375C',
#  'YMR312W',
#  'YKL013C',
#  'YGL172W',
#  'YNL201C',
#  'YOR232W',
#  'YDR296W',
#  'YLR192C',
#  'YGL150C',
#  'YNL149C',
#  'YGL242C',
#  'YBL039C',
#  'YDL218W',
#  'YHR111W',
#  'YEL054C',
#  'YDL117W',
#  'YBL016W',
#  'YPR046W',
#  'YNL249C',
#  'YIR001C',
#  'YNL287W',
#  'YEL013W',
#  'YHR091C',
#  'YDR383C',
#  'YBL091C',
#  'YMR280C',
#  'YDR054C',
#  'YML082W',
#  'YCR009C',
#  'YDR526C',
#  'YLR146C',
#  'YFL059W',
#  'YHR115C',
#  'YBR193C',
#  'YAL020C',
#  'YJL185C',
#  'YOR160W',
#  'YER126C',
#  'YJR074W',
#  'YOR158W',
#  'YGL122C',
#  'YMR124W',
#  'YGL187C',
#  'YBL025W',
#  'YNL155W',
#  'YLR219W',
#  'YPL013C',
#  'YLR117C',
#  'YOR347C',
#  'YPL192C',
#  'YLR321C',
#  'YDR353W',
#  'YIL079C',
#  'YDR145W',
#  'YDL203C',
#  'YNL233W',
#  'YDR008C',
#  'YKL142W',
#  'YMR186W',
#  'YER106W',
#  'YDR077W',
#  'YFR033C',
#  'YDR105C',
#  'YPL001W',
#  'YBR190W',
#  'YKL186C',
#  'YOL083W',
#  'YNL280C',
#  'YBR279W',
#  'YLR175W',
#  'YCR106W',
#  'YAL049C',
#  'YLL032C',
#  'YCR020C',
#  'YOR226C',
#  'YEL017W',
#  'YHR130C',
#  'YDR423C',
#  'YPL184C',
#  'YKR007W',
#  'YGL190C',
#  'YGL174W',
#  'YBR281C',
#  'YFL034CB',
#  'YMR298W',
#  'YLL036C',
#  'YDR091C',
#  'YPL095C',
#  'YNR068C',
#  'YCR011C',
#  'YDL120W',
#  'YNL127W',
#  'YIR037W',
#  'YGR121C',
#  'YKL144C',
#  'YBR187W',
#  'YGR189C',
#  'YDR284C',
#  'YBR244W',
#  'YHR014W',
#  'YPR070W',
#  'YOR379C',
#  'YBR122C',
#  'YMR092C',
#  'YNL210W',
#  'YFR052W',
#  ...]
